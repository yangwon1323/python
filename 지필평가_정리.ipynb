# %% [markdown]
# <a href="https://colab.research.google.com/github/yangwon1323/python/blob/main/%EC%A7%80%ED%95%84%ED%8F%89%EA%B0%80_%EC%A0%95%EB%A6%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. 파이썬 프로그래밍 언어의 장점
#
# -무료 오픈 소스
# -모바일 컴퓨팅 분야에 지원이 약함
# -다른 언어에 비해 실행 속도가 느림
# -다양하고 강력한 외부 라이브러리 제공
#
# 2. 파이썬 문법의 예약어
#
# -if
# -else
#
# 3. 키보드로부터 입력받는 값을 변수에 저장할 수 있도록 도와주는 함수
#
# num = input()
# print(num)
#
# 4. 연산자
#
# num = 4
# result = num // 2
#
# 5. 대입연산자
#
# - 여러개의 대입연산
#
# #n1 = 100
# #n1 , n2 = 100, 200
# #n1 , n2 , n3 = 100, 200, 300
# #n1 , n2 , n3 , n4 = 100, 200, 300, 400
# #n1 , n2 , n3 , n4 ,n5 = 100, 200, 300, 400, 500
# 5번
#
# 6. 비교연산자
#
# var1 = (30 > 300)
# var2 = (300 <= 300)
# var3 = (30 <= 300)
# var4 = (300> 300)
# var5 = (300 == 300)
#
# print(var1, var2, var3, var4, var5)
#
# 7. len() 함수
#
# var = "안산공업고등학교"
# len(var1)
#
# 8. lower() 함수
#
# var1 = "ansan"
# print(var1.lower())
#
# 9. count() 함수
#
# - 문자열에서 어떤 글자가  몇 번 등장하는 확인함
#
# var1 = "안산공업고등학교 컴퓨터과 "
# print(var1.count("컴퓨터과"))
#
# 10. 문자열의 위치
#
# school =  "안산공고"
# print(school[3], end='')
# print(school[2], end='')
# print(school[1], end='')
# print(school[0], end='')
#
# 11. 순차구조 - 선택구조 - 반복구조
#
# - 2가지중 하나의 흐름으로 실행되는 구조 (선택구조)
# - 순서대로만 실행되는 구조는 (순차구조)
# - 동일한 코드, 특별한 단계가 여러 번 반복해서 실향 (반복구조)
#
# 12. if문
#
# num = int(input("숫자==>"))
#
# if (number % 2 = 1)
#  print("홀수")
# else  :
#  print("짝수")
#
# 13. for문
#
#  for i in range(3)
#   print("안산공고")
#
# 14. 중첩 for문
#
#    for i in range(3)
#      for j in range(3)
#        print("안산공고")
#
# 15. 리스트
#
# a = (100)
# b = [3.14]
# c = ['안산']
# d = [TRUE]
# E = [FALSE]
#
# print(type(a))
# print(type(b))
# print(type(c))
# print(type(d))
# print(type(e))
#
# 16. 리스트 인덱싱
#
# numList = [10, 20, 30, 40]
#
# 17.함수의 장점
#
# - 에러 수정이 쉽다
# - 개발 시간을 단축할 수 있다.
# - 프로그램 유지 보수에 효과적이다.
# - 하나의 큰 프로그램을 기능별로 분리할 수 있다.
# - 이미 정의된 함수는 여러번 호출이 가능하다.
#
# 18. 함수의 정의
#
#  def fun1 () :
#   pass
#
# 19. 함수 안에서 사용되는 변수로 지역변수 대신에 무조건 전역번수 대신
#
# - global
#
# 20. 파일 읽기의 3단계
#
# 파일 열기 - 파일 읽기 - 파일닫기
#
# 21. 파이썬에서 기본적으로 제공하는 gul 라이브러리
#
# -tkinter
#
# 22. 윈도우 창의 제목을 설정
#
# window.title("simple calculator")
