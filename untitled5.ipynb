# %% [markdown]
# <a href="https://colab.research.google.com/github/yangwon1323/python/blob/main/untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

try:
  import pymysql
except ImportError :
  os.system("pip install pymysql")

# %%
try:
    conn = pymysql.connect(host='52.78.117.250',
                           port=50488,
                           user='won',
                           password='ansan',
                           db='com3116',
                           charset='utf8')
    db_info = conn.get_server_info()
    print('mysql version : ', db_info)
    cur = conn.cursor()

except Exception as e:
    print("mysql error :", e)
# Out:
# mysql version :  5.7.42-0ubuntu0.18.04.1

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/kig2929kig/db/main/Population%20by%20country%20.csv")
df
# Out:
#                        Country          Capital City  Population
# 0                  Afghanistan                 Kabul     4011770
# 1                      Albania       Tiranë (Tirana)      475577
# 2                      Algeria  El Djazaïr (Algiers)     2693542
# 3               American Samoa             Pago Pago       48526
# 4                      Andorra      Andorra la Vella       22614
# ..                         ...                   ...         ...
# 229  Wallis and Futuna Islands              Matu-Utu        1025
# 230             Western Sahara              El Aaiún      232388
# 231                      Yemen               Sana'a'     2779317
# 232                     Zambia                Lusaka     2523844
# 233                   Zimbabwe                Harare     1515016
#
# [234 rows x 3 columns]

# %%
sql = "create table 세계인구(국가 varchar(30) ,수도 varchar(20) ,인구수 float)"

cur.execute(sql)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-36-20521ac8fa9a> in <cell line: 3>()
#       1 sql = "create table 세계인구(국가 varchar(30) ,수도 varchar(20) ,인구수 float)"
#       2
# ----> 3 cur.execute(sql)
#
# /usr/local/lib/python3.10/dist-packages/pymysql/cursors.py in execute(self, query, args)
#     151         query = self.mogrify(query, args)
#     152
# --> 153         result = self._query(query)
#     154         self._executed = query
#     155         return result
#
# /usr/local/lib/python3.10/dist-packages/pymysql/cursors.py in _query(self, q)
#     320         conn = self._get_db()
#     321         self._clear_result()
# --> 322         conn.query(q)
#     323         self._do_get_result()
#     324         return self.rowcount
#
# /usr/local/lib/python3.10/dist-packages/pymysql/connections.py in query(self, sql, unbuffered)
# ...

# %%
sql = "drop table 세계인구"

cur.execute(sql)
# Out:
# 0

# %%
for country, capital, population in zip(df['Country'], df['Capital City'], df['Population']):
  print(country, capital, population)
# Out:
# Afghanistan Kabul 4011770
# Albania Tiranë (Tirana) 475577
# Algeria El Djazaïr (Algiers) 2693542
# American Samoa Pago Pago 48526
# Andorra Andorra la Vella 22614
# Angola Luanda 7774200
# Anguilla The Valley 1402
# Antigua and Barbuda St. John's 20764
# Argentina Buenos Aires 14966530
# Armenia Yerevan 1080324
# Aruba Oranjestad 29877
# Australia Canberra 447692
# Austria Wien (Vienna) 1900547
# Azerbaijan Baku 2285729
# Bahamas Nassau 279668
# Bahrain Al-Manamah (Manama) 564631
# Bangladesh Dhaka 19578421
# Barbados Bridgetown 89201
# Belarus Minsk 2004672
# Belgium Bruxelles-Brussel 2049510
# Belize Belmopan 22964
# Benin Cotonou 685458
# Bermuda Hamilton 10073
# Bhutan Thimphu 203297
# Bolivia (Plurinational State of) La Paz 1814087
# Bosnia and Herzegovina Sarajevo 342577
# Botswana Gaborone 269338
# Brazil Brasília 4469585
# British Virgin Islands Road Town 15137
# Brunei Darussalam Bandar Seri Begawan 40781
# Bulgaria Sofia 1272418
# Burkina Faso Ouagadougou 2531381
# ...

# %%
sql = "create table 세계인구(국가 varchar(50), 수도 varchar(50), 인구수 float)default charset=utf8"

cur.execute(sql)
# Out:
# 0

# %%
for country, capital, population in zip(df['Country'], df['Capital City'], df['Population']):

  sql = f'insert into 세계인구 values ("{country}", "{capital}", "{population}")'
  print(sql)
  cur.execute(sql)


conn.commit()
# Out:
# insert into 세계인구 values ("Afghanistan", "Kabul", "4011770")
# insert into 세계인구 values ("Albania", "Tiranë (Tirana)", "475577")
# insert into 세계인구 values ("Algeria", "El Djazaïr (Algiers)", "2693542")
# insert into 세계인구 values ("American Samoa", "Pago Pago", "48526")
# insert into 세계인구 values ("Andorra", "Andorra la Vella", "22614")
# insert into 세계인구 values ("Angola", "Luanda", "7774200")
# insert into 세계인구 values ("Anguilla", "The Valley", "1402")
# insert into 세계인구 values ("Antigua and Barbuda", "St. John's", "20764")
# insert into 세계인구 values ("Argentina", "Buenos Aires", "14966530")
# insert into 세계인구 values ("Armenia", "Yerevan", "1080324")
# insert into 세계인구 values ("Aruba", "Oranjestad", "29877")
# insert into 세계인구 values ("Australia", "Canberra", "447692")
# insert into 세계인구 values ("Austria", "Wien (Vienna)", "1900547")
# insert into 세계인구 values ("Azerbaijan", "Baku", "2285729")
# insert into 세계인구 values ("Bahamas", "Nassau", "279668")
# ...

# %%
while(True) :
  try :
    country = input("나라를 입력 : ")
    if country =="종료" :
      break;
    else :
      sql = f"select * from 세계인구 where 국가 = '{country}'"
      cur.execute(sql)
      result = cur.fetchone()

      print("국가 : " + result[0])
      print("수도 : " + result[1])
      print("수도의 인구 수 : ", result[2],"명")
  except :
    print("국가명을 잘못 입력했거나 없는 국가입니다.")

# %%
import random

def info_country() :
  rand = random.randrange(0, row_count)

  sql = f"select * from 세계인구"
  cur.execute(sql)
  result = ""

  for r in range(rand):
    result = cur.fetchone()
  return result


  sql = "select count(*) from 세계인구"
  cur.execute(sql)

  for r in cur.fetchall():
    row_count = r[0]

score = 0
for i in range(10) :
  info = info_country()
  c = input(f"{info[0]}의 수도를 입력 : ")
  if c == str(info[1]) :
    print("정답입니다.")
    score = score + 1
  else :
    print("오답입니다.")

print("당신의 점수는 : ",score,"점입니다")
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-42-1bc6eae4b31a> in <cell line: 22>()
#      21 score = 0
#      22 for i in range(10) :
# ---> 23   info = info_country()
#      24   c = input(f"{info[0]}의 수도를 입력 : ")
#      25   if c == str(info[1]) :
#
# <ipython-input-42-1bc6eae4b31a> in info_country()
#       2
#       3 def info_country() :
# ----> 4   rand = random.randrange(0, row_count)
#       5
#       6   sql = f"select * from 세계인구"
#
# UnboundLocalError: local variable 'row_count' referenced before assignment
